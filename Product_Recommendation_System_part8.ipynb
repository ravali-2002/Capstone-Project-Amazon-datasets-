# %% [markdown]
# # **PRODUCT RECOMMENDATION SYSTEM**
#
# ### **OBJECTIVE:** Building a Product Recommendation System to recommend similar products of the product purchased by the customer.
#
#
# **MODEL USED:** KNearest Neighbors model
#
#
# **MAIN COLUMNS USED:** asin(ProductID),main_cat,brand

# %%
# Importing Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Importing Libraries
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame 
import nltk

from sklearn.neighbors import NearestNeighbors
from sklearn import neighbors
#from scipy.spatial.distance import cosine
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
#from sklearn.feature_selection import SelectKBest
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelEncoder,StandardScaler
from scipy.sparse import csr_matrix

import re
import string
from wordcloud import WordCloud, STOPWORDS
from sklearn.metrics import mean_squared_error
from datetime import date

# %%
# Final dataset
final_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/A_final_data.csv')
final_df.head()
# Out:
#        reviewerID  product_id     reviewerName  verified  \
# 0  A2YCGMW0ZKPYZ2  0788602144  Bernard Perusse      True
# 1   A5N992ESD6UHW  0967680654        Jonny Lee      True
# 2  A35L775VMC0BKL  0967680654               Fm      True
# 3  A1ZJJKOC38Q622  0967680654            mitzi      True
# 4  A2S78BQKIPAMT7  0967680654         faithful      True
#
#                                           reviewText  rating        date  \
# 0  The answer, of course, is no. A lot of time ha...       4  2002-07-08
# 1  A bit outdated, from a special-effects/technol...       4  2016-06-21
# 2                                          Thank you       5  2015-11-18
# 3                                          very good       5  2015-01-21
# 4  This is good for someone who is trying to make...       5  2013-02-02
#
#                                              summary            brand  \
# 0                              Nostalgia: overrated?  Patrick Adiarte
# 1  Would be Nice to See This Effective Concept Re...     Daniel Kruse
# 2                                         Five Stars     Daniel Kruse
# 3                                         Five Stars     Daniel Kruse
# 4                                   Escape from Hell     Daniel Kruse
#
#                                     category     main_cat
# 0  CDs & Vinyl,Classic Rock,British Invasion  Movies & TV
# 1   CDs & Vinyl,Christian,Pop & Contemporary  Movies & TV
# 2   CDs & Vinyl,Christian,Pop & Contemporary  Movies & TV
# 3   CDs & Vinyl,Christian,Pop & Contemporary  Movies & TV
# 4   CDs & Vinyl,Christian,Pop & Contemporary  Movies & TV

# %%
# Shape
final_df.shape
# Out:
# (1373582, 11)

# %%
print("Total data of verified reviews ")
print("-"*50)
print("\nTotal no of ratings :",final_df.shape[0])
print("Total No of Users   :", len(np.unique(final_df.reviewerID)))
print("Total No of products  :", len(np.unique(final_df.product_id)))
# Out:
# Total data of verified reviews
# --------------------------------------------------
#
# Total no of ratings : 1373582
# Total No of Users   : 181049
# Total No of products  : 96631

# %%
# Getting the required columns
data = final_df[['product_id','brand','main_cat','rating','category']]

# %%
data.head()
# Out:
#    product_id            brand     main_cat  rating  \
# 0  0788602144  Patrick Adiarte  Movies & TV       4
# 1  0967680654     Daniel Kruse  Movies & TV       4
# 2  0967680654     Daniel Kruse  Movies & TV       5
# 3  0967680654     Daniel Kruse  Movies & TV       5
# 4  0967680654     Daniel Kruse  Movies & TV       5
#
#                                     category
# 0  CDs & Vinyl,Classic Rock,British Invasion
# 1   CDs & Vinyl,Christian,Pop & Contemporary
# 2   CDs & Vinyl,Christian,Pop & Contemporary
# 3   CDs & Vinyl,Christian,Pop & Contemporary
# 4   CDs & Vinyl,Christian,Pop & Contemporary

# %%
# Checking for missing values
data.isnull().sum()
# Out:
# product_id    0
# brand         0
# main_cat      0
# rating        0
# category      0
# dtype: int64

# %%
rating = pd.DataFrame(data.groupby(['product_id'])['rating'].mean()).reset_index()
rating.columns
# Out:
# Index(['product_id', 'rating'], dtype='object')

# %%
data = pd.merge(data[['product_id','brand','main_cat','category']],rating,on='product_id',how='inner')

# %%
data.shape
# Out:
# (1373582, 5)

# %%
# Dropping duplicates
data = data.drop_duplicates(keep='first')

# %%
# Shape of dataset 
data.shape
# Out:
# (96631, 5)

# %%
# Labelencoding categorical colunmns
data['main_cat'] =data['main_cat'].astype('category')
data['brand'] = data['brand'].astype('category')
data['category'] = data['category'].astype('category')

label_encoder = LabelEncoder()
data['main_cat_encode'] = label_encoder.fit_transform(data['main_cat'])
data['brand_encode'] = label_encoder.fit_transform(data['brand'])
data['category_encode'] = label_encoder.fit_transform(data['category'])

# %%
#Setting asin as index
data=data.set_index('product_id')
data.head()
# Out:
#                         brand     main_cat  \
# product_id
# 0788602144    Patrick Adiarte  Movies & TV
# 0967680654       Daniel Kruse  Movies & TV
# 0972179526    Dr. Harvey Karp  Movies & TV
# 1566054109        Pat Benatar  Movies & TV
# 3937406875  Dusty Springfield        Books
#
#                                                      category    rating  \
# product_id
# 0788602144          CDs & Vinyl,Classic Rock,British Invasion  4.666667
# 0967680654           CDs & Vinyl,Christian,Pop & Contemporary  4.600000
# 0972179526         CDs & Vinyl,Special Interest,Instructional  4.470588
# 1566054109  CDs & Vinyl,Classic Rock,Album-Oriented Rock (...  5.000000
# 3937406875                     CDs & Vinyl,World Music,Europe  4.583333
#
#             main_cat_encode  brand_encode  category_encode
# product_id
# 0788602144               24         16825               86
# 0967680654               24          5418               78
# 0972179526               24          6454              358
# 1566054109               24         16803               84
# 3937406875                9          6564              395

# %%
data_copy = data

# %%
#data = data[data.overall>3]

# %%
# Scaling the values
scaler = StandardScaler()
d_scaled = pd.DataFrame(scaler.fit_transform(data[['main_cat_encode','brand_encode','category_encode']]),columns=['main_cat_encode','brand_encode','category_encode'],index=data.index)

# %%
d_scaled.head()
# Out:
#             main_cat_encode  brand_encode  category_encode
# product_id
# 0788602144         1.230858      0.586620        -0.871596
# 0967680654         1.230858     -1.030622        -0.895845
# 0972179526         1.230858     -0.883741        -0.047134
# 1566054109         1.230858      0.583501        -0.877659
# 3937406875        -1.393009     -0.868146         0.065017

# %%
# model 
model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')

model_knn.fit(d_scaled)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
# Distances and indices
distances, indices = model_knn.kneighbors(d_scaled, n_neighbors = 5)
print('distances: ', distances.shape, 'indices: ', indices.shape)
# Out:
# distances:  (96631, 5) indices:  (96631, 5)

# %%
indices
# Out:
# array([[    0,     3,    15,    39,   655],
#        [    1,  1005,   250,   363,  1161],
#        [    2,    10,   384,   856,   318],
#        ...,
#        [96628, 80266, 74505, 79677, 86460],
#        [96629, 77305, 89099, 70690, 70696],
#        [96630, 84693, 85118, 82503, 80126]])

# %%
a=pd.DataFrame([d_scaled.index,indices])

# %%
a=a.T
a.rename(columns={0:'product_id',1:'Neighbors'},inplace=True)

# %%
a.head(10)
# Out:
#    product_id                        Neighbors
# 0  0788602144              [0, 3, 15, 39, 655]
# 1  0967680654        [1, 1005, 250, 363, 1161]
# 2  0972179526           [2, 10, 384, 856, 318]
# 3  1566054109              [3, 0, 15, 39, 655]
# 4  3937406875  [4, 68147, 43639, 83001, 94116]
# 5  5552622685  [5, 24141, 24627, 31716, 16773]
# 6  630025075X          [6, 1087, 756, 759, 14]
# 7  6301248252        [7, 578, 825, 1135, 1079]
# 8  6301236947          [8, 108, 1094, 57, 112]
# 9  6301334175           [9, 29, 501, 900, 987]

# %%
cat = data_copy[['brand','main_cat','rating','category']]
#cat = data1.groupby('main_cat')
cat.head()

b = pd.merge(a,cat,on='product_id',how='left')
b.head()
# Out:
#    product_id                        Neighbors              brand  \
# 0  0788602144              [0, 3, 15, 39, 655]    Patrick Adiarte
# 1  0967680654        [1, 1005, 250, 363, 1161]       Daniel Kruse
# 2  0972179526           [2, 10, 384, 856, 318]    Dr. Harvey Karp
# 3  1566054109              [3, 0, 15, 39, 655]        Pat Benatar
# 4  3937406875  [4, 68147, 43639, 83001, 94116]  Dusty Springfield
#
#       main_cat    rating                                           category
# 0  Movies & TV  4.666667          CDs & Vinyl,Classic Rock,British Invasion
# 1  Movies & TV  4.600000           CDs & Vinyl,Christian,Pop & Contemporary
# 2  Movies & TV  4.470588         CDs & Vinyl,Special Interest,Instructional
# 3  Movies & TV  5.000000  CDs & Vinyl,Classic Rock,Album-Oriented Rock (...
# 4        Books  4.583333                     CDs & Vinyl,World Music,Europe

# %%
b.shape
# Out:
# (96631, 6)

# %%
a.shape
# Out:
# (96631, 2)

# %%
b.shape
# Out:
# (96631, 6)

# %%
b.head(20)
# Out:
#     product_id                        Neighbors              brand  \
# 0   0788602144              [0, 3, 15, 39, 655]    Patrick Adiarte
# 1   0967680654        [1, 1005, 250, 363, 1161]       Daniel Kruse
# 2   0972179526           [2, 10, 384, 856, 318]    Dr. Harvey Karp
# 3   1566054109              [3, 0, 15, 39, 655]        Pat Benatar
# 4   3937406875  [4, 68147, 43639, 83001, 94116]  Dusty Springfield
# 5   5552622685  [5, 24141, 24627, 31716, 16773]  Bruce Springsteen
# 6   630025075X          [6, 1087, 756, 759, 14]      Michael Kamen
# 7   6301248252        [7, 578, 825, 1135, 1079]         The Police
# 8   6301236947          [8, 108, 1094, 57, 112]               Bono
# 9   6301334175           [9, 29, 501, 900, 987]         Pink Floyd
# 10  6301650662           [10, 2, 318, 856, 384]        Ed Flanders
# 11  6301846052        [11, 547, 245, 1100, 237]        Bryan Adams
# 12  6301955013         [12, 416, 333, 100, 793]    Joseph Forester
# 13  6301954920        [13, 564, 562, 505, 1065]         Bob Marley
# 14  6301879562          [14, 681, 1087, 6, 756]        Moody Blues
# 15  6302158249              [15, 39, 0, 3, 655]          Paul Comi
# 16  6302089824       [16, 191, 1053, 1118, 545]        Mario Lanza
# 17  6302250056         [17, 290, 788, 180, 583]        Jack Hedley
# 18  6302374286            [18, 79, 73, 44, 758]            Madonna
# 19  6302383366         [19, 359, 1242, 457, 92]               Cher
#
#        main_cat    rating                                           category
# 0   Movies & TV  4.666667          CDs & Vinyl,Classic Rock,British Invasion
# 1   Movies & TV  4.600000           CDs & Vinyl,Christian,Pop & Contemporary
# 2   Movies & TV  4.470588         CDs & Vinyl,Special Interest,Instructional
# 3   Movies & TV  5.000000  CDs & Vinyl,Classic Rock,Album-Oriented Rock (...
# 4         Books  4.583333                     CDs & Vinyl,World Music,Europe
# 5         Books  4.852941  CDs & Vinyl,Classic Rock,Album-Oriented Rock (...
# 6   Movies & TV  4.441860      CDs & Vinyl,Rock,Progressive,Progressive Rock
# 7   Movies & TV  4.500000  CDs & Vinyl,Alternative Rock,New Wave & Post-P...
# 8   Movies & TV  4.333333                  CDs & Vinyl,Pop,Adult Alternative
# 9   Movies & TV  4.476190      CDs & Vinyl,Rock,Progressive,Progressive Rock
# 10  Movies & TV  4.500000         CDs & Vinyl,Special Interest,Instructional
# 11  Movies & TV  4.717391      CDs & Vinyl,Rock,Progressive,Progressive Rock
# 12  Movies & TV  5.000000   CDs & Vinyl,World Music,Caribbean & Cuba,Jamaica
# 13  Movies & TV  4.333333   CDs & Vinyl,World Music,Caribbean & Cuba,Jamaica
# 14  Movies & TV  4.428571      CDs & Vinyl,Rock,Progressive,Progressive Rock
# 15  Movies & TV  4.222222  CDs & Vinyl,Classic Rock,Album-Oriented Rock (...
# 16  Movies & TV  3.750000                          CDs & Vinyl,Pop,Vocal Pop
# 17  Movies & TV  4.941176       CDs & Vinyl,Blues,Regional Blues,Texas Blues
# 18  Movies & TV  4.000000                 CDs & Vinyl,Pop,Adult Contemporary
# 19  Movies & TV  4.181818                 CDs & Vinyl,Pop,Adult Contemporary

# %%
b['main_cat'].value_counts()
# Out:
# Digital Music                    68553
# Office Products                  19954
# All Electronics                   2613
# Amazon Home                       1299
# Movies & TV                       1253
# Industrial & Scientific            566
# Arts, Crafts & Sewing              512
# Computers                          377
# Tools & Home Improvement           368
# Toys & Games                       238
# Health & Personal Care             208
# Books                              177
# Sports & Outdoors                  107
# Home Audio & Theater                52
# Cell Phones & Accessories           51
# All Beauty                          44
# Automotive                          42
# Camera & Photo                      36
# Amazon Fashion                      35
# Industrial &amp; Scientific         22
# Baby                                22
# Tools &amp; Home Improvement        20
# Arts, Crafts &amp; Sewing           19
# Toys &amp; Games                    16
# Pet Supplies                         8
# Musical Instruments                  7
# Software                             6
# Home Audio &amp; Theater             6
# Health &amp; Personal Care           6
# Buy a Kindle                         3
# Grocery                              3
# Sports &amp; Outdoors                3
# Cell Phones &amp; Accessories        2
# Portable Audio & Accessories         1
# Amazon Devices                       1
# Gift Cards                           1
# Name: main_cat, dtype: int64

# %%
# Defining function for the reccomendation system
def recommended_products(product_id):
  lst=[]
  m_ct=[]
  ct=[]
  br=[] 
  rate=[]
  main_cat=list(b['main_cat'][b.product_id==product_id])
  cat = list(b['category'][b.product_id==product_id])
  brand=list(b['brand'][b.product_id==product_id])
  rating=list(b['rating'][b.product_id==product_id])
  print('Purchased product is:',product_id,'\nMain Category:',main_cat[0],'\nCategory:',cat[0],'\nBrand:',brand[0],'\nRating:',rating[0])
  print('Recommended Products are:')
  similar_products=b['Neighbors'][b.product_id==product_id]
  for i in similar_products:
      lst.append(b['product_id'][i]) 
      m_ct.append(b['main_cat'][i])
      ct.append(b['category'][i])
      br.append(b['brand'][i])
      rate.append(b['rating'][i])

  df1 = pd.DataFrame(lst)
  df2 = pd.DataFrame(m_ct)
  df3 = pd.DataFrame(ct)
  df4 = pd.DataFrame(br)
  df5 = pd.DataFrame(rate)
  df = pd.concat([df1,df2,df3,df4,df5],axis=0)
  #df=df.T
  df = (df.T).reset_index()
  df.drop(columns='index',inplace=True)
  df=df[df.main_cat==main_cat[0]].reset_index()
  df.drop(columns='index',axis=1,inplace=True)
  df['rating']=df['rating'].apply(lambda x:round(x,2))
  df = df[df['rating']>3]

    
  return df

# %%
# Product recommendation
product_id = '0439394058'
x = recommended_products(product_id)
x
# Out:
# Purchased product is: 0439394058
# Main Category: Office Products
# Category: Office Products,Office &amp; School Supplies,Presentation Boards,Bulletin Boards
# Brand: Scholastic
# Rating: 4.625
# Recommended Products are:
#    product_id         main_cat  \
# 0  0439509769  Office Products
# 1  0439731593  Office Products
# 2  0545040116  Office Products
# 3  0439394058  Office Products
# 4  0545118239  Office Products
#
#                                             category       brand  rating
# 0  Office Products,Office &amp; School Supplies,P...  Scholastic    4.83
# 1  Office Products,Office &amp; School Supplies,P...  Scholastic    4.62
# 2  Office Products,Office &amp; School Supplies,P...  Scholastic    4.89
# 3  Office Products,Office &amp; School Supplies,P...  Scholastic    4.62
# 4  Office Products,Office &amp; School Supplies,P...  Scholastic    4.40

# %%
# Checking for products with low rating

product_id = 'B0012Z9OOA'
x = recommended_products(product_id)
x
# Out:
# Purchased product is: B0012Z9OOA
# Main Category: All Electronics
# Category: Office Products,Office Electronics,Telephones & Accessories,Landline Phones,Cordless Telephones
# Brand: Uniden
# Rating: 2.0
# Recommended Products are:
#    product_id         main_cat  \
# 0  B0050MMHIG  All Electronics
# 1  B000L00AUO  All Electronics
# 2  B001W0Y4E0  All Electronics
# 3  B001W0Y4GI  All Electronics
# 4  B0012Z9OPE  All Electronics
#
#                                             category   brand  rating
# 0  Office Products,Office Electronics,Telephones ...  Uniden    3.73
# 1  Office Products,Office Electronics,Telephones ...  Uniden    4.00
# 2  Office Products,Office Electronics,Telephones ...  Uniden    3.60
# 3  Office Products,Office Electronics,Telephones ...  Uniden    4.75
# 4  Office Products,Office Electronics,Telephones ...  Uniden    5.00

# %% [markdown]
# Thus similar products of the products purchased by the customer can be recommended using this recommendation system.
